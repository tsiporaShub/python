# %%
students = {'name': ['אליז', 'בת שבע', 'גליה'],
        'class': [25, 32, 180],
        'marks': 'ל אביב',90, '10']}

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_9608\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("Z:\B\פיפרמן חיה\PYTON\lesson5\cities.csv")
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.LatD = df.LatD.fillna(0)

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.drop_duplicates()
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df["LatD"].mean()
# Out:
# 38.8203125

# %%
df["LatD"].min()
# Out:
# 26

# %%
df["LatD"].max()
# Out:
# 50

# %%
df.insert(4,"ert",df["LatD"]/df["LatD"])

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"  ert   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"  1.0       80       39        0   "W"
# 1      42       52       48   "N"  1.0       97       23       23   "W"
# 2      46       35       59   "N"  1.0      120       30       36   "W"
# 3      42       16       12   "N"  1.0       71       48        0   "W"
# 4      43       37       48   "N"  1.0       89       46       11   "W"
# ..    ...      ...      ...   ...  ...      ...      ...      ...   ...
# 123    39       31       12   "N"  1.0      119       48       35   "W"
# 124    50       25       11   "N"  1.0      104       39        0   "W"
# 125    40       10       48   "N"  1.0      122       14       23   "W"
# 126    40       19       48   "N"  1.0       75       55       48   "W"
# 127    41        9       35   "N"  1.0       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# ...

# %%
df.rename(columns={'ert':'population'},inplace=True)
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"  population   "LonD"   "LonM"   "LonS"  \
# 0      41        5       59   "N"         1.0       80       39        0
# 1      42       52       48   "N"         1.0       97       23       23
# 2      46       35       59   "N"         1.0      120       30       36
# 3      42       16       12   "N"         1.0       71       48        0
# 4      43       37       48   "N"         1.0       89       46       11
# ..    ...      ...      ...   ...         ...      ...      ...      ...
# 123    39       31       12   "N"         1.0      119       48       35
# 124    50       25       11   "N"         1.0      104       39        0
# 125    40       10       48   "N"         1.0      122       14       23
# 126    40       19       48   "N"         1.0       75       55       48
# 127    41        9       35   "N"         1.0       81       14       23
#
#      "EW"              "City"  "State"
# 0     "W"        "Youngstown"       OH
# ...

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"  population   "LonD"   "LonM"   "LonS"  \
# 0      41        5       59   "N"         1.0       80       39        0
# 1      42       52       48   "N"         1.0       97       23       23
# 2      46       35       59   "N"         1.0      120       30       36
# 3      42       16       12   "N"         1.0       71       48        0
# 4      43       37       48   "N"         1.0       89       46       11
# ..    ...      ...      ...   ...         ...      ...      ...      ...
# 123    39       31       12   "N"         1.0      119       48       35
# 124    50       25       11   "N"         1.0      104       39        0
# 125    40       10       48   "N"         1.0      122       14       23
# 126    40       19       48   "N"         1.0       75       55       48
# 127    41        9       35   "N"         1.0       81       14       23
#
#      "EW"              "City"  "State"
# 0     "W"        "Youngstown"       OH
# ...

# %%
df[df["LatD"]==40]
# Out:
#      LatD   "LatM"   "LatS"  "NS"  population   "LonD"   "LonM"   "LonS"  \
# 15     40        4       11   "N"         1.0       80       43       12
# 45     40       13       47   "N"         1.0       74       46       11
# 58     40       59       24   "N"         1.0       75       11       24
# 61     40       21       36   "N"         1.0       80       37       12
# 62     40       37       11   "N"         1.0      103       13       12
# 96     40       45       35   "N"         1.0      111       52       47
# 125    40       10       48   "N"         1.0      122       14       23
# 126    40       19       48   "N"         1.0       75       55       48
#
#      "EW"             "City"  "State"
# 15    "W"         "Wheeling"       WV
# 45    "W"          "Trenton"       NJ
# 58    "W"      "Stroudsburg"       PA
# 61    "W"     "Steubenville"       OH
# 62    "W"         "Sterling"       CO
# 96    "W"   "Salt Lake City"       UT
# 125   "W"        "Red Bluff"       CA
# ...

# %%
df.rename(columns={' "State" ':'State'},inplace=True)

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"  population   "LonD"   "LonM"   "LonS"  \
# 0      41        5       59   "N"         1.0       80       39        0
# 1      42       52       48   "N"         1.0       97       23       23
# 2      46       35       59   "N"         1.0      120       30       36
# 3      42       16       12   "N"         1.0       71       48        0
# 4      43       37       48   "N"         1.0       89       46       11
# ..    ...      ...      ...   ...         ...      ...      ...      ...
# 123    39       31       12   "N"         1.0      119       48       35
# 124    50       25       11   "N"         1.0      104       39        0
# 125    40       10       48   "N"         1.0      122       14       23
# 126    40       19       48   "N"         1.0       75       55       48
# 127    41        9       35   "N"         1.0       81       14       23
#
#      "EW"              "City"  "State"
# 0     "W"        "Youngstown"       OH
# ...

# %%
df.sort_values(by=["LatD"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9608\2022393956.py in ?()
# ----> 1 df.sort_values(by=["LatD"]).descanding()
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'descanding'
